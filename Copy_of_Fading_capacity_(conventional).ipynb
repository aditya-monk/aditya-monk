# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-monk/aditya-monk/blob/main/Copy_of_Fading_capacity_(conventional).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score, mean_squared_log_error, explained_variance_score
import matplotlib.pyplot as plt

# Load the CSV file
data = pd.read_csv("mp input data ad.csv")

# Display the first few rows of the dataframe
print(data.head())
# Out:
#    time   time.1  battery_voltage  battery_current  max_discharge_current  \
# 0   0.0  0.00000              398              -10                    178
# 1   0.1  0.00003              398              -10                    178
# 2   0.2  0.00006              398              -10                    178
# 3   0.3  0.00008              398              -10                    178
# 4   0.4  0.00011              398              -10                    178
#
#    max_regenerative_current_LSB  battery_max_temperature  \
# 0                            25                       25
# 1                            25                       25
# 2                            25                       25
# 3                            25                       25
# 4                            25                       25
#
#    battery_min_temperature  cell_max_voltage  cell_min_voltage  ...  \
# 0                       14              3351              3325  ...
# ...

# %%
# Out:
# <ipython-input-15-3607fac83f74>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Fading_Capacity'] = fading_capacity

# %%
from sklearn.ensemble import RandomForestRegressor

# Create Random Forest model
rf_model = RandomForestRegressor()

# Train the model
rf_model.fit(X_train, y_train)

# Predict
rf_predictions = rf_model.predict(X_test)

# Evaluation
# Evaluate Random Forest model with different metrics
rf_mae = mean_absolute_error(y_test, rf_predictions)
rf_rmse = np.sqrt(mean_squared_error(y_test, rf_predictions))
rf_mape = mean_absolute_percentage_error(y_test, rf_predictions)
rf_r_squared = r2_score(y_test, rf_predictions)
rf_ev_score = explained_variance_score(y_test, rf_predictions)

# %%
from sklearn.tree import DecisionTreeRegressor

# Create Decision Tree model
dt_model = DecisionTreeRegressor()

# Train the model
dt_model.fit(X_train, y_train)

# Predict
dt_predictions = dt_model.predict(X_test)

# Evaluation
dt_mae = mean_absolute_error(y_test, dt_predictions)
dt_rmse = np.sqrt(mean_squared_error(y_test, dt_predictions))
dt_mape = mean_absolute_percentage_error(y_test, dt_predictions)
dt_r_squared = r2_score(y_test, dt_predictions)
dt_ev_score = explained_variance_score(y_test, dt_predictions)

# %%
from sklearn.neural_network import MLPRegressor

# Create MLP Regressor model
mlp_model = MLPRegressor()

# Train the model
mlp_model.fit(X_train, y_train)

# Predict
mlp_predictions = mlp_model.predict(X_test)

# Evaluation
mlp_mae = mean_absolute_error(y_test, mlp_predictions)
mlp_rmse = np.sqrt(mean_squared_error(y_test, mlp_predictions))
mlp_mape = mean_absolute_percentage_error(y_test, mlp_predictions)
mlp_r_squared = r2_score(y_test, mlp_predictions)
mlp_ev_score = explained_variance_score(y_test, mlp_predictions)

# %%
from sklearn.gaussian_process import GaussianProcessRegressor

# Create Gaussian Process Regressor model
gp_model = GaussianProcessRegressor()

# Train the model
gp_model.fit(X_train, y_train)

# Predict
gp_predictions = gp_model.predict(X_test)

# Evaluation
gp_mae = mean_absolute_error(y_test, gp_predictions)
gp_rmse = np.sqrt(mean_squared_error(y_test, gp_predictions))
gp_mape = mean_absolute_percentage_error(y_test, gp_predictions)
gp_r_squared = r2_score(y_test, gp_predictions)
gp_ev_score = explained_variance_score(y_test, gp_predictions)

# %%
import matplotlib.pyplot as plt

# Plot prediction outcome for Gaussian Process Regressor
plt.figure(figsize=(10, 6))
plt.scatter(y_test, gp_predictions, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.xlabel('Actual Fading Capacity')
plt.ylabel('Predicted Fading Capacity')
plt.title('Gaussian Process Regressor - Actual vs Predicted Fading Capacity')
plt.show()
